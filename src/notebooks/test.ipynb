# %%
import numpy as np
import pandas as pd

import sys
sys.path.insert(0, '..')
import utils.new_dataloader as dl

# %%
slot = 1
day = slot // 48
timeslot = slot - day*48
day, timeslot

48 % 48
# Out:
# 0

# %%
# Load data
train, eval, test = dl.getCustomerData('../../data/load1011.csv','../../data/load1112.csv','../../data/load1213.csv','../../data/price_wo_outlier.csv',13)

# %%
load_pv, price, price_norm = train

# %%
pd.DataFrame(price).plot()
# Out:
# <Axes: >
