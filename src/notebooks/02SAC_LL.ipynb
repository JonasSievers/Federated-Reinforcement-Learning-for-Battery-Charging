# %%
# Imports
import time
import os
import logging
import pandas as pd
import wandb
import tensorflow as tf

logging.getLogger("wandb").setLevel(logging.ERROR)
os.environ['WANDB_SILENT'] = 'true'
os.environ['WANDB_CONSOLE'] = 'off'

import sys
sys.path.insert(0, '..')
from utils.reinforcementLearningHelper import *
# Out:
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.
#
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tf_agents\typing\types.py:114: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#Setup Environments of selected buildings for training, evaluation, and testing

environments, observation_spec, action_spec  = setup_energymanagement_environments(num_buildings=30)

#Check environment setup
print(
    "Batch size:", environments["train"][f"building_1"].batch_size, 
    "/ State Space: {} / Action Space: {}".format(observation_spec.shape[0], action_spec.shape[0]),
    "/ Upper bound: {}".format(round(environments["train"][f"building_1"].action_spec().maximum.item(), 3)),
)
# Out:
# Batch size: 1 / State Space: 40 / Action Space: 1 / Upper bound: 2.3

# %%
# Setup Agent networks
SEED = 42
tf.random.set_seed(SEED)

batch_size = 128
replay_buffer_capacity = 20000 
initial_collect_steps = 2000
collect_steps_per_iteration = 30 
num_iterations = 10000 
eval_interval = num_iterations-10

num_rounds = 3
num_buildings = 30

# %%
# LOCAL LEARNING

result_df = pd.DataFrame(columns=['Building', 'Total Profit'])

start_time = time.time()

for idx in range(num_buildings):
    for round in range(num_rounds):
        building_index=idx+1
        print("Building: ", building_index, " - round: ", round)
        #0. Reset global step
        tf.compat.v1.reset_default_graph()
        global_step = tf.compat.v1.train.get_or_create_global_step()
        
        #1. Initalize agent
        tf_agent, eval_policy, collect_policy = initialize_sac_agent(observation_spec, action_spec, global_step, environments)

        #2. Prepare training pipeline: Setup iterator, replay buffer, driver
        iterator, collect_driver, time_step, policy_state = setup_rl_training_pipeline(
            tf_agent, environments["train"][f"building_{building_index}"], replay_buffer_capacity,collect_policy, 
            initial_collect_steps, collect_steps_per_iteration, batch_size
            )

        #3. Setup wandb logging
        artifact = initialize_wandb_logging(name=f"Exp_SAC_LL_Home{building_index}_rd{round}", num_iterations=num_iterations)

        #4. Train, evaluate agent and store weights
        result_df, metrics = agent_training_and_evaluation(global_step, num_iterations, collect_driver, 
                time_step, policy_state, iterator, tf_agent, eval_policy, building_index, result_df, eval_interval, environments)
            
        #6. End and log wandb
        end_and_log_wandb(metrics, artifact)

end_time = time.time()
time_taken = end_time - start_time
# Out:
# Building:  1  - round:  0
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tensorflow\python\autograph\impl\api.py:377: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.
# c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\src\notebooks\..\utils\reinforcementLearningHelper.py:355: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result_df = pd.concat([result_df, pd.DataFrame({'Building': [building_index], 'Total Profit': [wandb.summary["Final Profit"]]})], ignore_index=True)
# Building:  1  - Total Profit:  -1284.1798309748747
# Building:  1  - round:  1
# Building:  1  - Total Profit:  -1325.4588150401296
# Building:  1  - round:  2
# WARNING:tensorflow:5 out of the last 5 calls to <function AverageReturnMetric.reset at 0x000001FC07E7E050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <bound method DynamicEpisodeDriver.run of <tf_agents.drivers.dynamic_episode_driver.DynamicEpisodeDriver object at 0x000001FBF29D9F90>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TFDeque.mean at 0x000001FC092AF1C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function AverageReturnMetric.reset at 0x000001FBBC588310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <bound method DynamicEpisodeDriver.run of <tf_agents.drivers.dynamic_episode_driver.DynamicEpisodeDriver object at 0x000001FC09339270>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TFDeque.mean at 0x000001FC093F9A20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Building:  1  - Total Profit:  -1308.3491472397734
# Building:  2  - round:  0
# Building:  2  - Total Profit:  -1393.9620369683748
# Building:  2  - round:  1
# Building:  2  - Total Profit:  -1349.5690525099405
# Building:  2  - round:  2
# Building:  2  - Total Profit:  -1434.9533863023012
# Building:  3  - round:  0
# Building:  3  - Total Profit:  -534.7302802362489
# Building:  3  - round:  1
# Building:  3  - Total Profit:  -541.2036519544363
# Building:  3  - round:  2
# Building:  3  - Total Profit:  -593.2898451186452
# Building:  4  - round:  0
# Building:  4  - Total Profit:  -1191.7185910924375
# Building:  4  - round:  1
# Building:  4  - Total Profit:  -1162.5095919828111
# Building:  4  - round:  2
# Building:  4  - Total Profit:  -1162.3193200415012
# Building:  5  - round:  0
# Building:  5  - Total Profit:  -1240.9586840853242
# Building:  5  - round:  1
# Building:  5  - Total Profit:  -1270.1218676411602
# Building:  5  - round:  2
# Building:  5  - Total Profit:  -1276.9360139347348
# Building:  6  - round:  0
# Building:  6  - Total Profit:  -2825.6454363518674
# Building:  6  - round:  1
# Building:  6  - Total Profit:  -2895.1279158766547
# Building:  6  - round:  2
# Building:  6  - Total Profit:  -2840.2869216973922
# Building:  7  - round:  0
# Building:  7  - Total Profit:  -873.3794275311855
# Building:  7  - round:  1
# Building:  7  - Total Profit:  -929.939670871744
# Building:  7  - round:  2
# Building:  7  - Total Profit:  -852.8278645337188
# Building:  8  - round:  0
# Building:  8  - Total Profit:  -2906.9677527771264
# Building:  8  - round:  1
# Building:  8  - Total Profit:  -3069.377788605554
# Building:  8  - round:  2
# Building:  8  - Total Profit:  -3041.6282159515986
# Building:  9  - round:  0
# Building:  9  - Total Profit:  -1084.8195040090168
# Building:  9  - round:  1
# Building:  9  - Total Profit:  -1033.515604394838
# Building:  9  - round:  2
# Building:  9  - Total Profit:  -1106.4752518985636
# Building:  10  - round:  0
# Building:  10  - Total Profit:  -1186.5694165694922
# Building:  10  - round:  1
# Building:  10  - Total Profit:  -1201.5667582731326
# Building:  10  - round:  2
# Building:  10  - Total Profit:  -1219.8660997429747
# Building:  11  - round:  0
# Building:  11  - Total Profit:  -1319.2442740182962
# Building:  11  - round:  1
# Building:  11  - Total Profit:  -1352.0344494242859
# Building:  11  - round:  2
# Building:  11  - Total Profit:  -1424.888590157356
# Building:  12  - round:  0
# Building:  12  - Total Profit:  -1289.6094251586253
# Building:  12  - round:  1
# Building:  12  - Total Profit:  -1286.5318713948147
# Building:  12  - round:  2
# Building:  12  - Total Profit:  -1261.2396692365521
# Building:  13  - round:  0
# Building:  13  - Total Profit:  -764.6160559347517
# Building:  13  - round:  1
# Building:  13  - Total Profit:  -814.6240335355867
# Building:  13  - round:  2
# Building:  13  - Total Profit:  -837.5209848684209
# Building:  14  - round:  0
# Building:  14  - Total Profit:  -1029.9984744249216
# Building:  14  - round:  1
# Building:  14  - Total Profit:  -1004.2835242388597
# Building:  14  - round:  2
# Building:  14  - Total Profit:  -1148.7000663036524
# Building:  15  - round:  0
# Building:  15  - Total Profit:  -877.9266086230564
# Building:  15  - round:  1
# Building:  15  - Total Profit:  -896.6364374913926
# Building:  15  - round:  2
# Building:  15  - Total Profit:  -854.7043618996356
# Building:  16  - round:  0
# Building:  16  - Total Profit:  -1469.932532108098
# Building:  16  - round:  1
# Building:  16  - Total Profit:  -1327.3415571390963
# Building:  16  - round:  2
# Building:  16  - Total Profit:  -1417.6581311414805
# Building:  17  - round:  0
# Building:  17  - Total Profit:  -1922.4503615365638
# Building:  17  - round:  1
# Building:  17  - Total Profit:  -1930.63623461696
# Building:  17  - round:  2
# Building:  17  - Total Profit:  -1929.1811539228063
# Building:  18  - round:  0
# Building:  18  - Total Profit:  -1850.2307609860063
# Building:  18  - round:  1
# Building:  18  - Total Profit:  -1861.4574156163837
# Building:  18  - round:  2
# Building:  18  - Total Profit:  -1829.9471731853753
# Building:  19  - round:  0
# Building:  19  - Total Profit:  -582.883763046333
# Building:  19  - round:  1
# Building:  19  - Total Profit:  -666.4460127255838
# Building:  19  - round:  2
# Building:  19  - Total Profit:  -642.4400090681668
# Building:  20  - round:  0
# Building:  20  - Total Profit:  -1651.3298377737697
# Building:  20  - round:  1
# Building:  20  - Total Profit:  -1618.0485346764476
# Building:  20  - round:  2
# Building:  20  - Total Profit:  -1677.045540748342
# Building:  21  - round:  0
# Building:  21  - Total Profit:  -2259.353448418266
# Building:  21  - round:  1
# Building:  21  - Total Profit:  -2106.436784729107
# Building:  21  - round:  2
# Building:  21  - Total Profit:  -2050.9721535329145
# Building:  22  - round:  0
# Building:  22  - Total Profit:  -992.6757855727167
# Building:  22  - round:  1
# Building:  22  - Total Profit:  -990.0361612566494
# Building:  22  - round:  2
# Building:  22  - Total Profit:  -1002.492304395633
# Building:  23  - round:  0
# Building:  23  - Total Profit:  -1238.201011431401
# Building:  23  - round:  1
# Building:  23  - Total Profit:  -1212.0747189552476
# Building:  23  - round:  2
# Building:  23  - Total Profit:  -1190.5909004878665
# Building:  24  - round:  0
# Building:  24  - Total Profit:  -652.8289779034045
# Building:  24  - round:  1
# Building:  24  - Total Profit:  -639.1070216727755
# Building:  24  - round:  2
# Building:  24  - Total Profit:  -611.8907177109
# Building:  25  - round:  0
# Building:  25  - Total Profit:  -1571.674097803594
# Building:  25  - round:  1
# Building:  25  - Total Profit:  -1533.9270496502672
# Building:  25  - round:  2
# Building:  25  - Total Profit:  -1556.052841475982
# Building:  26  - round:  0
# Building:  26  - Total Profit:  -1944.8975647990483
# Building:  26  - round:  1
# Building:  26  - Total Profit:  -1926.5157440855394
# Building:  26  - round:  2
# Building:  26  - Total Profit:  -1917.3625723183814
# Building:  27  - round:  0
# Building:  27  - Total Profit:  -1265.4909596321224
# Building:  27  - round:  1
# Building:  27  - Total Profit:  -1265.0165818391474
# Building:  27  - round:  2
# Building:  27  - Total Profit:  -1297.4189786278962
# Building:  28  - round:  0
# Building:  28  - Total Profit:  -766.2260800779437
# Building:  28  - round:  1
# Building:  28  - Total Profit:  -763.7892772958379
# Building:  28  - round:  2
# Building:  28  - Total Profit:  -805.5572353554286
# Building:  29  - round:  0
# Building:  29  - Total Profit:  -1220.9151503183318
# Building:  29  - round:  1
# Building:  29  - Total Profit:  -1242.9675898525134
# Building:  29  - round:  2
# Building:  29  - Total Profit:  -1431.11657555616
# Building:  30  - round:  0
# Building:  30  - Total Profit:  -849.3413819725536
# Building:  30  - round:  1
# Building:  30  - Total Profit:  -947.4480561420165
# Building:  30  - round:  2
# Building:  30  - Total Profit:  -905.4814483335906

# %%
# Save results
result_df.rename(columns={'Total Profit': 'Profit'}, inplace=True)
result_df['Setup'] = 'SAC_LL'
result_df['Time'] = time_taken
result_df.index.name = 'Building_nr'
result_df.reset_index(inplace=True, drop=True)
os.makedirs('results', exist_ok=True)
result_df.to_csv(f'results/SAC_LL_results_Time.csv', index=False)
print("Final reuslt: ", result_df["Profit"].sum())
# Out:
# Final reuslt:  -120835.70076041241

# %%
time_taken
# Out:
# 20596.590861320496

# %%
import requests

def send_telegram_message(bot_token, chat_id, message):
    """Send a message to a Telegram chat via the Bot API."""
    url = f"https://api.telegram.org/bot{bot_token}/sendMessage"
    payload = {
        "chat_id": chat_id,
        "text": message,
        "parse_mode": "Markdown"
    }
    response = requests.post(url, json=payload)
    return response.json()

# Use the function
bot_token = os.getenv('TELEGRAM_BOT_TOKEN')
chat_id = os.getenv('TELEGRAM_CHAT_ID')
message = f"Script SAC LL Time ist fertig at .81!"

result = send_telegram_message(bot_token, chat_id, message)
print(result)
# Out:
# {'ok': True, 'result': {'message_id': 94, 'from': {'id': 7071194232, 'is_bot': True, 'first_name': 'Reinforcement Learning', 'username': 'FederatedRL_Bot'}, 'chat': {'id': 5493937056, 'first_name': 'Jonas', 'last_name': 'Sievers', 'username': 'JonasSievers', 'type': 'private'}, 'date': 1717658213, 'text': 'Script SAC LL Time ist fertig at .81!'}}
