# %%
# Imports
import os
import logging
import pandas as pd
import wandb
import tensorflow as tf

logging.getLogger("wandb").setLevel(logging.ERROR)
os.environ['WANDB_SILENT'] = 'true'
os.environ['WANDB_CONSOLE'] = 'off'

import sys
sys.path.insert(0, '..')
from utils.reinforcementLearningHelper import *
# Out:
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.
#
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tf_agents\typing\types.py:114: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#Setup Environments of selected buildings for training, evaluation, and testing

environments, observation_spec, action_spec  = setup_energymanagement_environments(num_buildings=30)

#Check environment setup
print(
    "Batch size:", environments["train"][f"building_1"].batch_size, 
    "/ State Space: {} / Action Space: {}".format(observation_spec.shape[0], action_spec.shape[0]),
    "/ Upper bound: {}".format(round(environments["train"][f"building_1"].action_spec().maximum.item(), 3)),
)
# Out:
# Batch size: 1 / State Space: 22 / Action Space: 1 / Upper bound: 2.3

# %%
# Setup Agent networks
SEED = 42
tf.random.set_seed(SEED)

batch_size = 128
replay_buffer_capacity = 20000 
initial_collect_steps = 2000
collect_steps_per_iteration = 30 
num_iterations = 10000 
eval_interval = num_iterations-10

num_rounds = 3
num_buildings = 30

# %%
# LOCAL LEARNING

result_df = pd.DataFrame(columns=['Building', 'Total Profit'])

for idx in range(num_buildings):
    for round in range(num_rounds):
        building_index=idx+1
        print("Building: ", building_index, " - round: ", round)
        #0. Reset global step
        tf.compat.v1.reset_default_graph()
        global_step = tf.compat.v1.train.get_or_create_global_step()
        
        #1. Initalize agent
        tf_agent, eval_policy, collect_policy = initialize_sac_agent(observation_spec, action_spec, global_step, environments)

        #2. Prepare training pipeline: Setup iterator, replay buffer, driver
        iterator, collect_driver, time_step, policy_state = setup_rl_training_pipeline(
            tf_agent, environments["train"][f"building_{building_index}"], replay_buffer_capacity,collect_policy, 
            initial_collect_steps, collect_steps_per_iteration, batch_size
            )

        #3. Setup wandb logging
        artifact = initialize_wandb_logging(name=f"Exp_SAC_LL_Home{building_index}_rd{round}", num_iterations=num_iterations)

        #4. Train, evaluate agent and store weights
        result_df, metrics = agent_training_and_evaluation(global_step, num_iterations, collect_driver, 
                time_step, policy_state, iterator, tf_agent, eval_policy, building_index, result_df, eval_interval, environments)
            
        #6. End and log wandb
        end_and_log_wandb(metrics, artifact)
# Out:
# Building:  1  - round:  0
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tensorflow\python\autograph\impl\api.py:377: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.
# c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\src\notebooks\..\utils\reinforcementLearningHelper.py:353: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result_df = pd.concat([result_df, pd.DataFrame({'Building': [building_index], 'Total Profit': [wandb.summary["Final Profit"]]})], ignore_index=True)
# Building:  1  - Total Profit:  -1315.9763787910954
# Building:  1  - round:  1
# Building:  1  - Total Profit:  -1332.9685153469802
# Building:  1  - round:  2
# WARNING:tensorflow:5 out of the last 5 calls to <function AverageReturnMetric.reset at 0x00000235270B30A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <bound method DynamicEpisodeDriver.run of <tf_agents.drivers.dynamic_episode_driver.DynamicEpisodeDriver object at 0x0000023527072950>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TFDeque.mean at 0x00000235270F0D30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function AverageReturnMetric.reset at 0x00000235270F0E50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <bound method DynamicEpisodeDriver.run of <tf_agents.drivers.dynamic_episode_driver.DynamicEpisodeDriver object at 0x00000235270224D0>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TFDeque.mean at 0x00000235886591B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Building:  1  - Total Profit:  -1322.8228903037773
# Building:  2  - round:  0
# Building:  2  - Total Profit:  -1307.944518605736
# Building:  2  - round:  1
# Building:  2  - Total Profit:  -1351.9303377837105
# Building:  2  - round:  2
# Building:  2  - Total Profit:  -1412.6958120317706
# Building:  3  - round:  0
# Building:  3  - Total Profit:  -597.5042643985291
# Building:  3  - round:  1
# Building:  3  - Total Profit:  -531.0278145972464
# Building:  3  - round:  2
# Building:  3  - Total Profit:  -516.2247726146834
# Building:  4  - round:  0
# Building:  4  - Total Profit:  -1380.8587357207325
# Building:  4  - round:  1
# Building:  4  - Total Profit:  -1081.3904113065225
# Building:  4  - round:  2
# Building:  4  - Total Profit:  -1122.8438424564424
# Building:  5  - round:  0
# Building:  5  - Total Profit:  -1288.9946531850665
# Building:  5  - round:  1
# Building:  5  - Total Profit:  -1293.196174968462
# Building:  5  - round:  2
# Building:  5  - Total Profit:  -1253.1640881420853
# Building:  6  - round:  0
# Building:  6  - Total Profit:  -2919.97266082381
# Building:  6  - round:  1
# Building:  6  - Total Profit:  -2956.8671274115163
# Building:  6  - round:  2
# Building:  6  - Total Profit:  -2991.938957489239
# Building:  7  - round:  0
# Building:  7  - Total Profit:  -895.6980315713071
# Building:  7  - round:  1
# Building:  7  - Total Profit:  -928.522286318957
# Building:  7  - round:  2
# Building:  7  - Total Profit:  -964.5741720192835
# Building:  8  - round:  0
# Building:  8  - Total Profit:  -2880.875803803418
# Building:  8  - round:  1
# Building:  8  - Total Profit:  -2797.1292343875543
# Building:  8  - round:  2
# Building:  8  - Total Profit:  -2951.737513231078
# Building:  9  - round:  0
# Building:  9  - Total Profit:  -1011.1486679417017
# Building:  9  - round:  1
# Building:  9  - Total Profit:  -1057.4810103955951
# Building:  9  - round:  2
# Building:  9  - Total Profit:  -1035.7409138555297
# Building:  10  - round:  0
# Building:  10  - Total Profit:  -1286.1839610529105
# Building:  10  - round:  1
# Building:  10  - Total Profit:  -1290.651117397505
# Building:  10  - round:  2
# Building:  10  - Total Profit:  -1281.2663903615176
# Building:  11  - round:  0
# Building:  11  - Total Profit:  -1407.7108894893279
# Building:  11  - round:  1
# Building:  11  - Total Profit:  -1592.744271634622
# Building:  11  - round:  2
# Building:  11  - Total Profit:  -1415.5944309714025
# Building:  12  - round:  0
# Building:  12  - Total Profit:  -1295.768626245331
# Building:  12  - round:  1
# Building:  12  - Total Profit:  -1269.797047995237
# Building:  12  - round:  2
# Building:  12  - Total Profit:  -1250.6069161035653
# Building:  13  - round:  0
# Building:  13  - Total Profit:  -806.89823437542
# Building:  13  - round:  1
# Building:  13  - Total Profit:  -791.9605740839364
# Building:  13  - round:  2
# Building:  13  - Total Profit:  -814.848876847844
# Building:  14  - round:  0
# Building:  14  - Total Profit:  -1048.3915458501426
# Building:  14  - round:  1
# Building:  14  - Total Profit:  -1036.2576538033834
# Building:  14  - round:  2
# Building:  14  - Total Profit:  -1093.1405405160294
# Building:  15  - round:  0
# Building:  15  - Total Profit:  -860.3295341475775
# Building:  15  - round:  1
# Building:  15  - Total Profit:  -870.9358953455414
# Building:  15  - round:  2
# Building:  15  - Total Profit:  -862.9039925904949
# Building:  16  - round:  0
# Building:  16  - Total Profit:  -1377.5612410395381
# Building:  16  - round:  1
# Building:  16  - Total Profit:  -1430.5161797031985
# Building:  16  - round:  2
# Building:  16  - Total Profit:  -1507.6427210573952
# Building:  17  - round:  0
# Building:  17  - Total Profit:  -2031.7615578607506
# Building:  17  - round:  1
# Building:  17  - Total Profit:  -1964.5442486379752
# Building:  17  - round:  2
# Building:  17  - Total Profit:  -1901.0288316827014
# Building:  18  - round:  0
# Building:  18  - Total Profit:  -2092.3966076987685
# Building:  18  - round:  1
# Building:  18  - Total Profit:  -2019.8435447131064
# Building:  18  - round:  2
# Building:  18  - Total Profit:  -2002.188976625169
# Building:  19  - round:  0
# Building:  19  - Total Profit:  -553.6564853943389
# Building:  19  - round:  1
# Building:  19  - Total Profit:  -550.7194173371214
# Building:  19  - round:  2
# Building:  19  - Total Profit:  -658.9038838074971
# Building:  20  - round:  0
# Building:  20  - Total Profit:  -1626.589123630856
# Building:  20  - round:  1
# Building:  20  - Total Profit:  -1716.192872437637
# Building:  20  - round:  2
# Building:  20  - Total Profit:  -1633.1544271266632
# Building:  21  - round:  0
# Building:  21  - Total Profit:  -2255.0970651110906
# Building:  21  - round:  1
# Building:  21  - Total Profit:  -2040.9878474691297
# Building:  21  - round:  2
# Building:  21  - Total Profit:  -2172.202626362841
# Building:  22  - round:  0
# Building:  22  - Total Profit:  -1167.29019481528
# Building:  22  - round:  1
# Building:  22  - Total Profit:  -1086.170704379754
# Building:  22  - round:  2
# Building:  22  - Total Profit:  -1060.0269571001413
# Building:  23  - round:  0
# Building:  23  - Total Profit:  -1201.9437412287448
# Building:  23  - round:  1
# Building:  23  - Total Profit:  -1173.2936499730474
# Building:  23  - round:  2
# Building:  23  - Total Profit:  -1169.9698255182354
# Building:  24  - round:  0
# Building:  24  - Total Profit:  -713.0616985225396
# Building:  24  - round:  1
# Building:  24  - Total Profit:  -688.7514165367999
# Building:  24  - round:  2
# Building:  24  - Total Profit:  -772.1973976872264
# Building:  25  - round:  0
# Building:  25  - Total Profit:  -1716.9112481649297
# Building:  25  - round:  1
# Building:  25  - Total Profit:  -1789.5105907898085
# Building:  25  - round:  2
# Building:  25  - Total Profit:  -1704.1389793808032
# Building:  26  - round:  0
# Building:  26  - Total Profit:  -1899.9634853518166
# Building:  26  - round:  1
# Building:  26  - Total Profit:  -1925.9528510458897
# Building:  26  - round:  2
# Building:  26  - Total Profit:  -1928.337578567606
# Building:  27  - round:  0
# Building:  27  - Total Profit:  -1341.2567703613477
# Building:  27  - round:  1
# Building:  27  - Total Profit:  -1373.3638643953086
# Building:  27  - round:  2
# Building:  27  - Total Profit:  -1375.3552835411474
# Building:  28  - round:  0
# Building:  28  - Total Profit:  -821.6356896800096
# Building:  28  - round:  1
# Building:  28  - Total Profit:  -866.6035904606543
# Building:  28  - round:  2
# Building:  28  - Total Profit:  -755.5793625598513
# Building:  29  - round:  0
# Building:  29  - Total Profit:  -1202.4789732395352
# Building:  29  - round:  1
# Building:  29  - Total Profit:  -1264.494001676705
# Building:  29  - round:  2
# Building:  29  - Total Profit:  -1353.2821079026553
# Building:  30  - round:  0
# Building:  30  - Total Profit:  -882.810866573126
# Building:  30  - round:  1
# Building:  30  - Total Profit:  -954.1320146775122
# Building:  30  - round:  2
# Building:  30  - Total Profit:  -903.8176340937106

# %%
# Save results
result_df.rename(columns={'Total Profit': 'Profit'}, inplace=True)
result_df['Setup'] = 'SAC_LL'
result_df.index.name = 'Building_nr'
result_df.reset_index(inplace=True, drop=True)
os.makedirs('results', exist_ok=True)
result_df.to_csv(f'results/SAC_LL_results_setting_A.csv', index=False)
print("Final reuslt: ", result_df["Profit"].sum())
# Out:
# Final reuslt:  -123404.53822423358

# %%
import requests

def send_telegram_message(bot_token, chat_id, message):
    """Send a message to a Telegram chat via the Bot API."""
    url = f"https://api.telegram.org/bot{bot_token}/sendMessage"
    payload = {
        "chat_id": chat_id,
        "text": message,
        "parse_mode": "Markdown"
    }
    response = requests.post(url, json=payload)
    return response.json()

# Use the function
bot_token = os.getenv('TELEGRAM_BOT_TOKEN')
chat_id = os.getenv('TELEGRAM_CHAT_ID')
message = f"Script SAC LL ist fertig!"

result = send_telegram_message(bot_token, chat_id, message)
print(result)
# Out:
# {'ok': True, 'result': {'message_id': 8, 'from': {'id': 7071194232, 'is_bot': True, 'first_name': 'Reinforcement Learning', 'username': 'FederatedRL_Bot'}, 'chat': {'id': 5493937056, 'first_name': 'Jonas', 'last_name': 'Sievers', 'username': 'JonasSievers', 'type': 'private'}, 'date': 1714581103, 'text': 'Script SAC LL ist fertig!'}}
