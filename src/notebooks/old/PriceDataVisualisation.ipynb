# %%
import sys
sys.path.insert(0, '..')
import utils.dataloader as dl
import numpy as np
import matplotlib.pyplot as plt

# %%
price = (dl.loadPrice('../../data/price.csv')).drop(columns=['REGION', 'SETTLEMENTDATE', 'TOTALDEMAND', 'PERIODTYPE']).div(1000).squeeze()
plt.ylim(0, .5)
plt.plot(price)

# %%
np.percentile(price,99)
# Out:
# 0.26608060000000033

# %%
np.percentile(price,10)
# Out:
# 0.055240000000000004

# %%
price
# Out:
# 0        0.07462
# 1        0.06491
# 2        0.06080
# 3        0.06362
# 4        0.06212
#           ...
# 17515    0.06568
# 17516    0.05578
# 17517    0.05315
# 17518    0.06026
# 17519    0.06335
# Name: RRP, Length: 17520, dtype: float64

# %%
out = price.reindex(index=np.roll(price.index,335))
out
# Out:
# 17185    0.06652
# 17186    0.06777
# 17187    0.06916
# 17188    0.06372
# 17189    0.05950
#           ...
# 17180    0.07040
# 17181    0.06677
# 17182    0.06480
# 17183    0.06033
# 17184    0.05647
# Name: RRP, Length: 17520, dtype: float64

# %%
out.iloc[0:336]
# Out:
# 17185    0.06652
# 17186    0.06777
# 17187    0.06916
# 17188    0.06372
# 17189    0.05950
#           ...
# 17516    0.05578
# 17517    0.05315
# 17518    0.06026
# 17519    0.06335
# 0        0.07462
# Name: RRP, Length: 336, dtype: float64

# %%
min(1,2,3)
# Out:
# 1
