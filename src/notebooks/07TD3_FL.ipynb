# %%
#Imports
import os
import tensorflow as tf

import sys
sys.path.insert(0, '..')
from utils.federatedAggregation import FederatedAggregation
from utils.reinforcementLearningHelper import *
from utils.federatedLearningHelper import *
# Out:
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.
#
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tf_agents\typing\types.py:114: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#Setup Environments of selected buildings for training, evaluation, and testing

environments, observation_spec, action_spec  = setup_energymanagement_environments(num_buildings=30)

#Check environment setup
print(
    "Batch size:", environments["train"][f"building_1"].batch_size, 
    "/ State Space: {} / Action Space: {}".format(observation_spec.shape[0], action_spec.shape[0]),
    "/ Upper bound: {}".format(round(environments["train"][f"building_1"].action_spec().maximum.item(), 3)),
)
# Out:
# Batch size: 1 / State Space: 22 / Action Space: 1 / Upper bound: 2.3

# %%
# Cluster similar buildings (K-Means with DTW)

#Set parameter
num_clusters = 8 # 2, 6, 10, 12, 14, 16, 18

clustered_buildings = load_clustered_buildings(num_clusters)
clustered_buildings
# Out:
# {0: array([ 7, 25], dtype=int64),
#  1: array([16, 17, 21], dtype=int64),
#  2: array([ 5, 12, 13, 19, 20, 23, 24, 26, 27, 28, 29], dtype=int64),
#  3: array([18], dtype=int64),
#  4: array([ 3,  4,  9, 14, 15, 22, 30], dtype=int64),
#  5: array([1], dtype=int64),
#  6: array([6, 8], dtype=int64),
#  7: array([ 2, 10, 11], dtype=int64)}

# %%
# Setup Agent networks
federated_rounds = 10
batch_size = 128
replay_buffer_capacity = 20000 #-> only <18.000 samples per dataset
initial_collect_steps = 2000 #2000
collect_steps_per_iteration = 30 
num_iterations = 10000 #10000
eval_interval = num_iterations - 10 #9999

# %%
# FEDERATED LEARNING - Initalization Round 0

tf.compat.v1.reset_default_graph()
global_step = tf.compat.v1.train.get_or_create_global_step()

#Initalize a global model for each Cluster of similar buildings
for cluster in range(num_clusters):
        
        # 1. Build global agent per cluster
        first_building_in_cluster = clustered_buildings[cluster][0]
        global_td3_agent, global_eval_policy, global_collect_policy = initialize_td3_agent(
                observation_spec=observation_spec, action_spec=action_spec, global_step=global_step, environments=environments,
                )

        # 2. Initially store weights
        model_dir = os.path.join(os.getcwd(), f"models/td3/cluster_{cluster}/FLround{0}_c{num_clusters}_AvgAgg")
        os.makedirs(model_dir, exist_ok=True)
        
        save_td3_weights(global_td3_agent, model_dir)
# Out:
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
#FEDERATED LEARNING - Model training for multiple Rounds

#For each federated round and cluster
for federated_round  in range(federated_rounds):
    for cluster_number, buildings_in_cluster in clustered_buildings.items():

        #Iterate through the buildings per cluster
        print(f"Cluster {cluster_number}: Buildings {buildings_in_cluster} Federated round ---", federated_round+1, f"/ {federated_rounds}")
        local_storage = {
            "actor_weights": [], "critic_weights_1": [], "performance_metrics": []
            }
        
        for building_index in buildings_in_cluster:
            
            #0. Reset global step
            tf.compat.v1.reset_default_graph()
            global_step = tf.compat.v1.train.get_or_create_global_step()
            
            #1. Initalize local agent
            local_td3_agent, local_eval_policy, local_collect_policy = initialize_td3_agent(
                observation_spec = observation_spec, action_spec = action_spec,
                global_step = global_step, environments = environments,
                )
            
            #2. Set global weights of this training round to agent (loads the weights of last training)
            model_dir = os.path.join(os.getcwd(), f"models/td3/cluster_{cluster_number}/FLround{federated_round}_c{num_clusters}_AvgAgg")
            local_td3_agent = set_weights_to_td3_agent(local_td3_agent, model_dir)
            
            #3. Prepare training pipeline: Setup iterator, replay buffer, driver
            local_iterator, local_collect_driver, local_time_step, local_policy_state = setup_rl_training_pipeline(
                local_td3_agent, environments["train"][f"building_{building_index}"], replay_buffer_capacity,
                local_collect_policy, initial_collect_steps, collect_steps_per_iteration, batch_size
                )
            
            #4. Train, evaluate agent and store weights
            local_td3_agent, local_storage = local_agent_training_and_evaluation(
                local_iterator, local_collect_driver, local_time_step, local_policy_state, global_step, 
                local_td3_agent, local_eval_policy, local_storage, building_index, num_iterations, environments, agent_type="td3"
                )           

        # Performe Federated aggregation
        average_actor_weights = FederatedAggregation.federated_weigthed_aggregation(local_storage["actor_weights"], local_storage["performance_metrics"])
        average_critic_weights_1 = FederatedAggregation.federated_weigthed_aggregation(local_storage["critic_weights_1"], local_storage["performance_metrics"]) 
        
        #Save federated weights for next round (Round + 1)
        model_dir = os.path.join(os.getcwd(), f"models/td3/cluster_{cluster_number}/FLround{federated_round+1}_c{num_clusters}_AvgAgg")
        os.makedirs(model_dir, exist_ok=True)
        save_federated_td3_weights(model_dir, average_actor_weights, average_critic_weights_1)
# Out:
# Cluster 0: Buildings [ 7 25] Federated round --- 1 / 10
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tensorflow\python\autograph\impl\api.py:377: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.
# Return:  -4807.751
# Return:  -5618.7744
# Cluster 1: Buildings [16 17 21] Federated round --- 1 / 10
# Return:  -8550.019
# Return:  -7282.063
# WARNING:tensorflow:5 out of the last 5 calls to <function AverageReturnMetric.reset at 0x00000190FE7F1AB0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <bound method DynamicEpisodeDriver.run of <tf_agents.drivers.dynamic_episode_driver.DynamicEpisodeDriver object at 0x00000190F27680D0>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TFDeque.mean at 0x00000190FE7F1240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Return:  -11178.383
# Cluster 2: Buildings [ 5 12 13 19 20 23 24 26 27 28 29] Federated round --- 1 / 10
# WARNING:tensorflow:6 out of the last 6 calls to <function AverageReturnMetric.reset at 0x0000019083F74AF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <bound method DynamicEpisodeDriver.run of <tf_agents.drivers.dynamic_episode_driver.DynamicEpisodeDriver object at 0x000001910C77ED40>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TFDeque.mean at 0x00000190EF97B130> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Return:  -3579.685
# Return:  -5166.447
# Return:  -3579.0232
# Return:  -1782.8379
# Return:  -4405.5264
# Return:  -5057.333
# Return:  -2717.8386
# Return:  -7218.3394
# Return:  -5829.9653
# Return:  -3377.0176
# Return:  -4773.966
# Cluster 3: Buildings [18] Federated round --- 1 / 10
# Return:  -7418.394
# Cluster 4: Buildings [ 3  4  9 14 15 22 30] Federated round --- 1 / 10
# Return:  -2933.9595
# Return:  -4785.39
# Return:  -4707.384
# Return:  -2684.027
# Return:  -2782.5234
# Return:  -3936.0635
# Return:  -3273.0852
# Cluster 5: Buildings [1] Federated round --- 1 / 10
# Return:  -5668.4575
# Cluster 6: Buildings [6 8] Federated round --- 1 / 10
# Return:  -9930.782
# Return:  -12637.926
# Cluster 7: Buildings [ 2 10 11] Federated round --- 1 / 10
# Return:  -7884.05
# Return:  -6460.085
# Return:  -5535.578
# Cluster 0: Buildings [ 7 25] Federated round --- 2 / 10
# Return:  -4800.949
# Return:  -5602.3325
# Cluster 1: Buildings [16 17 21] Federated round --- 2 / 10
# Return:  -8566.309
# Return:  -7283.389
# Return:  -11109.409
# Cluster 2: Buildings [ 5 12 13 19 20 23 24 26 27 28 29] Federated round --- 2 / 10
# Return:  -3544.3035
# Return:  -5144.8853
# Return:  -3552.9985
# Return:  -1764.0746
# Return:  -4003.6736
# Return:  -5057.383
# Return:  -2605.5415
# Return:  -7201.193
# Return:  -5791.8364
# Return:  -3351.5476
# Return:  -4656.6104
# Cluster 3: Buildings [18] Federated round --- 2 / 10
# Return:  -7371.5713
# Cluster 4: Buildings [ 3  4  9 14 15 22 30] Federated round --- 2 / 10
# Return:  -2888.711
# Return:  -4727.6367
# Return:  -4695.2607
# Return:  -2673.686
# Return:  -2776.7898
# Return:  -3974.1792
# Return:  -3236.8296
# Cluster 5: Buildings [1] Federated round --- 2 / 10
# Return:  -5659.713
# Cluster 6: Buildings [6 8] Federated round --- 2 / 10
# Return:  -10008.81
# Return:  -12641.819
# Cluster 7: Buildings [ 2 10 11] Federated round --- 2 / 10
# Return:  -7538.399
# Return:  -6469.069
# Return:  -5513.031
# Cluster 0: Buildings [ 7 25] Federated round --- 3 / 10
# Return:  -4773.3433
# Return:  -5508.6943
# Cluster 1: Buildings [16 17 21] Federated round --- 3 / 10
# Return:  -8535.84
# Return:  -7550.945
# Return:  -11229.206
# Cluster 2: Buildings [ 5 12 13 19 20 23 24 26 27 28 29] Federated round --- 3 / 10
# Return:  -3533.0757
# Return:  -5137.7075
# Return:  -3566.0293
# Return:  -1737.9833
# Return:  -3952.5308
# Return:  -5104.631
# Return:  -2630.4922
# Return:  -7206.5635
# Return:  -5780.577
# Return:  -3327.9602
# Return:  -4649.8813
# Cluster 3: Buildings [18] Federated round --- 3 / 10
# Return:  -7361.683
# Cluster 4: Buildings [ 3  4  9 14 15 22 30] Federated round --- 3 / 10
# Return:  -2899.378
# Return:  -4727.28
# Return:  -4687.784
# Return:  -2673.7031
# Return:  -2771.1968
# Return:  -3953.7341
# Return:  -3226.3975
# Cluster 5: Buildings [1] Federated round --- 3 / 10
# Return:  -5632.256
# Cluster 6: Buildings [6 8] Federated round --- 3 / 10
# Return:  -9930.551
# Return:  -12627.252
# Cluster 7: Buildings [ 2 10 11] Federated round --- 3 / 10
# Return:  -7565.5835
# Return:  -6490.6377
# Return:  -5496.8037
# Cluster 0: Buildings [ 7 25] Federated round --- 4 / 10
# Return:  -4753.443
# Return:  -5348.628
# Cluster 1: Buildings [16 17 21] Federated round --- 4 / 10
# Return:  -8567.568
# Return:  -7213.9995
# Return:  -11173.6455
# Cluster 2: Buildings [ 5 12 13 19 20 23 24 26 27 28 29] Federated round --- 4 / 10
# Return:  -3551.3354
# Return:  -5140.5073
# Return:  -3573.3794
# Return:  -1711.9971
# Return:  -3868.8772
# Return:  -5066.342
# Return:  -2635.7217
# Return:  -7210.097
# Return:  -5791.1567
# Return:  -3295.2979
# Return:  -4640.2925
# Cluster 3: Buildings [18] Federated round --- 4 / 10
# Return:  -7373.167
# Cluster 4: Buildings [ 3  4  9 14 15 22 30] Federated round --- 4 / 10
# Return:  -2941.8665
# Return:  -4716.577
# Return:  -4688.33
# Return:  -2656.266
# Return:  -2781.3145
# Return:  -3936.5134
# Return:  -3207.4575
# Cluster 5: Buildings [1] Federated round --- 4 / 10
# Return:  -5639.5645
# Cluster 6: Buildings [6 8] Federated round --- 4 / 10
# Return:  -9871.632
# Return:  -12593.274
# Cluster 7: Buildings [ 2 10 11] Federated round --- 4 / 10
# Return:  -7602.489
# Return:  -6453.0757
# Return:  -5499.2207
# Cluster 0: Buildings [ 7 25] Federated round --- 5 / 10
# Return:  -4753.6357
# Return:  -5317.004
# Cluster 1: Buildings [16 17 21] Federated round --- 5 / 10
# Return:  -8515.919
# Return:  -7189.873
# Return:  -11036.053
# Cluster 2: Buildings [ 5 12 13 19 20 23 24 26 27 28 29] Federated round --- 5 / 10
# Return:  -3553.2576
# Return:  -5131.417
# Return:  -3573.3052
# Return:  -1696.0027
# Return:  -3760.3948
# Return:  -4999.647
# Return:  -2622.1426
# Return:  -7207.9297
# Return:  -5789.0083
# Return:  -3247.2769
# Return:  -4624.891
# Cluster 3: Buildings [18] Federated round --- 5 / 10
# Return:  -7679.0186
# Cluster 4: Buildings [ 3  4  9 14 15 22 30] Federated round --- 5 / 10
# Return:  -2913.1228
# Return:  -4761.729
# Return:  -4668.106
# Return:  -2676.9736
# Return:  -2779.625
# Return:  -3914.5334
# Return:  -3197.7986
# Cluster 5: Buildings [1] Federated round --- 5 / 10
# Return:  -5627.0063
# Cluster 6: Buildings [6 8] Federated round --- 5 / 10
# Return:  -9880.153
# Return:  -12577.671
# Cluster 7: Buildings [ 2 10 11] Federated round --- 5 / 10
# Return:  -7548.69
# Return:  -6479.7153
# Return:  -5481.071
# Cluster 0: Buildings [ 7 25] Federated round --- 6 / 10
# Return:  -4760.434
# Return:  -5281.32
# Cluster 1: Buildings [16 17 21] Federated round --- 6 / 10
# Return:  -8551.621
# Return:  -7151.5635
# Return:  -11003.279
# Cluster 2: Buildings [ 5 12 13 19 20 23 24 26 27 28 29] Federated round --- 6 / 10
# Return:  -3539.3828
# Return:  -5127.0483
# Return:  -3547.834
# Return:  -1714.846
# Return:  -3722.0278
# Return:  -5032.167
# Return:  -2632.64
# Return:  -7207.1084
# Return:  -5775.3667
# Return:  -3243.199
# Return:  -4620.627
# Cluster 3: Buildings [18] Federated round --- 6 / 10
# Return:  -7405.5205
# Cluster 4: Buildings [ 3  4  9 14 15 22 30] Federated round --- 6 / 10
# Return:  -2901.9802
# Return:  -4712.567
# Return:  -4701.9414
# Return:  -2692.8113
# Return:  -2791.621
# Return:  -3903.9521
# Return:  -3261.0684
# Cluster 5: Buildings [1] Federated round --- 6 / 10
# Return:  -5628.8774
# Cluster 6: Buildings [6 8] Federated round --- 6 / 10
# Return:  -9887.546
# Return:  -12573.547
# Cluster 7: Buildings [ 2 10 11] Federated round --- 6 / 10
# Return:  -7524.336
# Return:  -6434.7847
# Return:  -5481.2407
# Cluster 0: Buildings [ 7 25] Federated round --- 7 / 10
# Return:  -4766.22
# Return:  -5251.589
# Cluster 1: Buildings [16 17 21] Federated round --- 7 / 10
# Return:  -8539.937
# Return:  -7155.421
# Return:  -11011.618
# Cluster 2: Buildings [ 5 12 13 19 20 23 24 26 27 28 29] Federated round --- 7 / 10
# Return:  -3554.8528
# Return:  -5125.6455
# Return:  -3577.9727
# Return:  -1701.645
# Return:  -3723.7375
# Return:  -5012.3496
# Return:  -2626.8875
# Return:  -7204.9556
# Return:  -5785.622
# Return:  -3255.7375
# Return:  -4616.26
# Cluster 3: Buildings [18] Federated round --- 7 / 10
# Return:  -7407.474
# Cluster 4: Buildings [ 3  4  9 14 15 22 30] Federated round --- 7 / 10
# Return:  -2896.2473
# Return:  -4711.622
# Return:  -4731.6074
# Return:  -2665.315
# Return:  -2785.5051
# Return:  -3952.4763
# Return:  -3238.5967
# Cluster 5: Buildings [1] Federated round --- 7 / 10
# Return:  -5626.0786
# Cluster 6: Buildings [6 8] Federated round --- 7 / 10
# Return:  -9860.493
# Return:  -12543.874
# Cluster 7: Buildings [ 2 10 11] Federated round --- 7 / 10
# Return:  -7512.1763
# Return:  -6444.921
# Return:  -5467.293
# Cluster 0: Buildings [ 7 25] Federated round --- 8 / 10
# Return:  -4760.3784
# Return:  -5285.121
# Cluster 1: Buildings [16 17 21] Federated round --- 8 / 10
# Return:  -8536.293
# Return:  -7134.865
# Return:  -11013.3
# Cluster 2: Buildings [ 5 12 13 19 20 23 24 26 27 28 29] Federated round --- 8 / 10
# Return:  -3534.6145
# Return:  -5129.9023
# Return:  -3560.316
# Return:  -1719.7853
# Return:  -3675.141
# Return:  -5026.4927
# Return:  -2632.989
# Return:  -7209.3076
# Return:  -5785.489
# Return:  -3232.0247
# Return:  -4607.533
# Cluster 3: Buildings [18] Federated round --- 8 / 10
# Return:  -7418.0474
# Cluster 4: Buildings [ 3  4  9 14 15 22 30] Federated round --- 8 / 10
# Return:  -2900.701
# Return:  -4718.7363
# Return:  -4646.399
# Return:  -2656.9915
# Return:  -2781.4463
# Return:  -3883.0732
# Return:  -3227.5452
# Cluster 5: Buildings [1] Federated round --- 8 / 10
# Return:  -5634.815
# Cluster 6: Buildings [6 8] Federated round --- 8 / 10
# Return:  -9806.002
# Return:  -12578.843
# Cluster 7: Buildings [ 2 10 11] Federated round --- 8 / 10
# Return:  -7531.041
# Return:  -6449.6445
# Return:  -5486.349
# Cluster 0: Buildings [ 7 25] Federated round --- 9 / 10
# Return:  -4758.4136
# Return:  -5280.216
# Cluster 1: Buildings [16 17 21] Federated round --- 9 / 10
# Return:  -8560.038
# Return:  -7260.2334
# Return:  -11012.292
# Cluster 2: Buildings [ 5 12 13 19 20 23 24 26 27 28 29] Federated round --- 9 / 10
# Return:  -3558.5864
# Return:  -5126.839
# Return:  -3550.5618
# Return:  -1717.3427
# Return:  -3677.3088
# Return:  -5008.977
# Return:  -2640.725
# Return:  -7214.096
# Return:  -5776.4907
# Return:  -3252.5334
# Return:  -4604.4854
# Cluster 3: Buildings [18] Federated round --- 9 / 10
# Return:  -7367.733
# Cluster 4: Buildings [ 3  4  9 14 15 22 30] Federated round --- 9 / 10
# Return:  -2905.1404
# Return:  -4681.96
# Return:  -4659.6904
# Return:  -2630.7634
# Return:  -2805.807
# Return:  -3891.5498
# Return:  -3173.2698
# Cluster 5: Buildings [1] Federated round --- 9 / 10
# Return:  -5639.391
# Cluster 6: Buildings [6 8] Federated round --- 9 / 10
# Return:  -9851.98
# Return:  -12597.831
# Cluster 7: Buildings [ 2 10 11] Federated round --- 9 / 10
# Return:  -7516.5356
# Return:  -6465.255
# Return:  -5476.73
# Cluster 0: Buildings [ 7 25] Federated round --- 10 / 10
# Return:  -4791.909
# Return:  -5237.42
# Cluster 1: Buildings [16 17 21] Federated round --- 10 / 10
# Return:  -8554.067
# Return:  -7286.143
# Return:  -11010.749
# Cluster 2: Buildings [ 5 12 13 19 20 23 24 26 27 28 29] Federated round --- 10 / 10
# Return:  -3539.2346
# Return:  -5125.3193
# Return:  -3566.8083
# Return:  -1726.168
# Return:  -3681.7935
# Return:  -5007.695
# Return:  -2662.6155
# Return:  -7203.9526
# Return:  -5784.3135
# Return:  -3267.5217
# Return:  -4615.6743
# Cluster 3: Buildings [18] Federated round --- 10 / 10
# Return:  -7361.903
# Cluster 4: Buildings [ 3  4  9 14 15 22 30] Federated round --- 10 / 10
# Return:  -2893.7393
# Return:  -4716.8916
# Return:  -4707.2886
# Return:  -2629.661
# Return:  -2775.4924
# Return:  -3903.457
# Return:  -3185.211
# Cluster 5: Buildings [1] Federated round --- 10 / 10
# Return:  -5641.5835
# Cluster 6: Buildings [6 8] Federated round --- 10 / 10
# Return:  -9830.791
# Return:  -12556.884
# Cluster 7: Buildings [ 2 10 11] Federated round --- 10 / 10
# Return:  -7525.1655
# Return:  -6422.1133
# Return:  -5490.794

# %%
# LOCAL REFITTING AND EVALUATION

best_federated_round = 3
num_rounds=3
num_test_iterations = 1000

result_df = pd.DataFrame(columns=['Building', 'Total Profit'])

for cluster_number, buildings_in_cluster in clustered_buildings.items():
    for building_index in buildings_in_cluster:
        
        for round in range(num_rounds):
            print("Cluster: ", cluster_number, " - Building: ", building_index, " - round: ", round)
            
            #0. Reset global step
            tf.compat.v1.reset_default_graph()
            global_step = tf.compat.v1.train.get_or_create_global_step()

            #1. Initalize local agent
            tf_td3_agent, eval_policy, collect_policy = initialize_td3_agent(
                observation_spec = observation_spec, action_spec = action_spec,
                global_step = global_step, environments = environments,
                )
            
            #2. Set global weights of this training round to agent (loads the weights of last training)
            model_dir = os.path.join(os.getcwd(), f"models/td3/cluster_{cluster_number}/FLround{best_federated_round}_c{num_clusters}_AvgAgg")
            tf_agent = set_weights_to_td3_agent(tf_td3_agent, model_dir)

            #3. Prepare training pipeline: Setup iterator, replay buffer, driver
            iterator, collect_driver, time_step, policy_state = setup_rl_training_pipeline(
                tf_td3_agent, environments["train"][f"building_{building_index}"], replay_buffer_capacity,
                collect_policy, initial_collect_steps, collect_steps_per_iteration, batch_size
                )
            
            #4. Setup wandb logging
            artifact = initialize_wandb_logging(name=f"Exp_building{building_index}_rd{round}", num_iterations=num_iterations)
            
            #5. Train, evaluate agent and store weights
            result_df, metrics = agent_training_and_evaluation(global_step, num_test_iterations, collect_driver, 
                time_step, policy_state, iterator, tf_td3_agent, eval_policy, building_index, result_df, eval_interval, environments)
            
            #6. End and log wandb
            end_and_log_wandb(metrics, artifact)
# Out:
# Cluster:  0  - Building:  7  - round:  0
# c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\src\notebooks\..\utils\reinforcementLearningHelper.py:353: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result_df = pd.concat([result_df, pd.DataFrame({'Building': [building_index], 'Total Profit': [wandb.summary["Final Profit"]]})], ignore_index=True)
# Building:  7  - Total Profit:  -793.2391286964753
# Cluster:  0  - Building:  7  - round:  1
# Building:  7  - Total Profit:  -793.3545453049873
# Cluster:  0  - Building:  7  - round:  2
# Building:  7  - Total Profit:  -791.9361662872524
# Cluster:  0  - Building:  25  - round:  0
# Building:  25  - Total Profit:  -1444.9361400760106
# Cluster:  0  - Building:  25  - round:  1
# Building:  25  - Total Profit:  -1445.1235810431383
# Cluster:  0  - Building:  25  - round:  2
# Building:  25  - Total Profit:  -1446.1770850677897
# Cluster:  1  - Building:  16  - round:  0
# Building:  16  - Total Profit:  -1278.8133197157358
# Cluster:  1  - Building:  16  - round:  1
# Building:  16  - Total Profit:  -1257.9523888919455
# Cluster:  1  - Building:  16  - round:  2
# Building:  16  - Total Profit:  -1268.6229254351886
# Cluster:  1  - Building:  17  - round:  0
# Building:  17  - Total Profit:  -1852.5264355966249
# Cluster:  1  - Building:  17  - round:  1
# Building:  17  - Total Profit:  -1848.3232185632212
# Cluster:  1  - Building:  17  - round:  2
# Building:  17  - Total Profit:  -1857.9602393330579
# Cluster:  1  - Building:  21  - round:  0
# Building:  21  - Total Profit:  -2000.732755793996
# Cluster:  1  - Building:  21  - round:  1
# Building:  21  - Total Profit:  -1996.9360223922445
# Cluster:  1  - Building:  21  - round:  2
# Building:  21  - Total Profit:  -2000.3318310017485
# Cluster:  2  - Building:  5  - round:  0
# Building:  5  - Total Profit:  -1111.9594676070321
# Cluster:  2  - Building:  5  - round:  1
# Building:  5  - Total Profit:  -1110.306392312991
# Cluster:  2  - Building:  5  - round:  2
# Building:  5  - Total Profit:  -1111.8795188506344
# Cluster:  2  - Building:  12  - round:  0
# Building:  12  - Total Profit:  -1151.7872437022056
# Cluster:  2  - Building:  12  - round:  1
# Building:  12  - Total Profit:  -1151.7341102415523
# Cluster:  2  - Building:  12  - round:  2
# Building:  12  - Total Profit:  -1151.7225625775427
# Cluster:  2  - Building:  13  - round:  0
# Building:  13  - Total Profit:  -693.0696662026711
# Cluster:  2  - Building:  13  - round:  1
# Building:  13  - Total Profit:  -692.3278711542206
# Cluster:  2  - Building:  13  - round:  2
# Building:  13  - Total Profit:  -691.3081596757709
# Cluster:  2  - Building:  19  - round:  0
# Building:  19  - Total Profit:  -401.7880589110055
# Cluster:  2  - Building:  19  - round:  1
# Building:  19  - Total Profit:  -399.9122564140134
# Cluster:  2  - Building:  19  - round:  2
# Building:  19  - Total Profit:  -401.7294723409079
# Cluster:  2  - Building:  20  - round:  0
# Building:  20  - Total Profit:  -1521.612893809997
# Cluster:  2  - Building:  20  - round:  1
# Building:  20  - Total Profit:  -1528.7376463186479
# Cluster:  2  - Building:  20  - round:  2
# Building:  20  - Total Profit:  -1519.423271993311
# Cluster:  2  - Building:  23  - round:  0
# Building:  23  - Total Profit:  -1069.262089838893
# Cluster:  2  - Building:  23  - round:  1
# Building:  23  - Total Profit:  -1066.530299637974
# Cluster:  2  - Building:  23  - round:  2
# Building:  23  - Total Profit:  -1065.812897347691
# Cluster:  2  - Building:  24  - round:  0
# Building:  24  - Total Profit:  -592.3366688285112
# Cluster:  2  - Building:  24  - round:  1
# Building:  24  - Total Profit:  -594.3703904696013
# Cluster:  2  - Building:  24  - round:  2
# Building:  24  - Total Profit:  -595.163192084912
# Cluster:  2  - Building:  26  - round:  0
# Building:  26  - Total Profit:  -1831.1222730677564
# Cluster:  2  - Building:  26  - round:  1
# Building:  26  - Total Profit:  -1831.2703451743932
# Cluster:  2  - Building:  26  - round:  2
# Building:  26  - Total Profit:  -1832.040853785086
# Cluster:  2  - Building:  27  - round:  0
# Building:  27  - Total Profit:  -1131.9577601890087
# Cluster:  2  - Building:  27  - round:  1
# Building:  27  - Total Profit:  -1130.6524572780554
# Cluster:  2  - Building:  27  - round:  2
# Building:  27  - Total Profit:  -1131.333833243572
# Cluster:  2  - Building:  28  - round:  0
# Building:  28  - Total Profit:  -669.0705192111002
# Cluster:  2  - Building:  28  - round:  1
# Building:  28  - Total Profit:  -672.3942631092627
# Cluster:  2  - Building:  28  - round:  2
# Building:  28  - Total Profit:  -671.8220913915729
# Cluster:  2  - Building:  29  - round:  0
# Building:  29  - Total Profit:  -1063.8739538257475
# Cluster:  2  - Building:  29  - round:  1
# Building:  29  - Total Profit:  -1063.1090383046158
# Cluster:  2  - Building:  29  - round:  2
# Building:  29  - Total Profit:  -1063.3393697491608
# Cluster:  3  - Building:  18  - round:  0
# Building:  18  - Total Profit:  -1699.0762480775936
# Cluster:  3  - Building:  18  - round:  1
# Building:  18  - Total Profit:  -1699.6991703933759
# Cluster:  3  - Building:  18  - round:  2
# Building:  18  - Total Profit:  -1697.5751881369692
# Cluster:  4  - Building:  3  - round:  0
# Building:  3  - Total Profit:  -356.21453673852835
# Cluster:  4  - Building:  3  - round:  1
# Building:  3  - Total Profit:  -355.3395103683387
# Cluster:  4  - Building:  3  - round:  2
# Building:  3  - Total Profit:  -355.62867201378776
# Cluster:  4  - Building:  4  - round:  0
# Building:  4  - Total Profit:  -983.7334994165187
# Cluster:  4  - Building:  4  - round:  1
# Building:  4  - Total Profit:  -985.1808515501964
# Cluster:  4  - Building:  4  - round:  2
# Building:  4  - Total Profit:  -981.3317534900268
# Cluster:  4  - Building:  9  - round:  0
# Building:  9  - Total Profit:  -875.5435575054873
# Cluster:  4  - Building:  9  - round:  1
# Building:  9  - Total Profit:  -874.4639646812118
# Cluster:  4  - Building:  9  - round:  2
# Building:  9  - Total Profit:  -872.8000975394436
# Cluster:  4  - Building:  14  - round:  0
# Building:  14  - Total Profit:  -900.1281050800096
# Cluster:  4  - Building:  14  - round:  1
# Building:  14  - Total Profit:  -897.0773314036753
# Cluster:  4  - Building:  14  - round:  2
# Building:  14  - Total Profit:  -897.1293286296805
# Cluster:  4  - Building:  15  - round:  0
# Building:  15  - Total Profit:  -685.8047822744272
# Cluster:  4  - Building:  15  - round:  1
# Building:  15  - Total Profit:  -685.3435361354278
# Cluster:  4  - Building:  15  - round:  2
# Building:  15  - Total Profit:  -684.6521562165482
# Cluster:  4  - Building:  22  - round:  0
# Building:  22  - Total Profit:  -826.1876988218776
# Cluster:  4  - Building:  22  - round:  1
# Building:  22  - Total Profit:  -826.1094717735209
# Cluster:  4  - Building:  22  - round:  2
# Building:  22  - Total Profit:  -827.7941349103398
# Cluster:  4  - Building:  30  - round:  0
# Building:  30  - Total Profit:  -723.3579777529808
# Cluster:  4  - Building:  30  - round:  1
# Building:  30  - Total Profit:  -721.8771450434801
# Cluster:  4  - Building:  30  - round:  2
# Building:  30  - Total Profit:  -721.228567341767
# Cluster:  5  - Building:  1  - round:  0
# Building:  1  - Total Profit:  -1267.8401027736572
# Cluster:  5  - Building:  1  - round:  1
# Building:  1  - Total Profit:  -1266.9513326822241
# Cluster:  5  - Building:  1  - round:  2
# Building:  1  - Total Profit:  -1267.1396380468027
# Cluster:  6  - Building:  6  - round:  0
# Building:  6  - Total Profit:  -2775.0275991744356
# Cluster:  6  - Building:  6  - round:  1
# Building:  6  - Total Profit:  -2774.227829255779
# Cluster:  6  - Building:  6  - round:  2
# Building:  6  - Total Profit:  -2774.9876348956022
# Cluster:  6  - Building:  8  - round:  0
# Building:  8  - Total Profit:  -2751.2985079747295
# Cluster:  6  - Building:  8  - round:  1
# Building:  8  - Total Profit:  -2761.9647261003965
# Cluster:  6  - Building:  8  - round:  2
# Building:  8  - Total Profit:  -2755.6083629466993
# Cluster:  7  - Building:  2  - round:  0
# Building:  2  - Total Profit:  -1177.3357089576016
# Cluster:  7  - Building:  2  - round:  1
# Building:  2  - Total Profit:  -1177.3446538969765
# Cluster:  7  - Building:  2  - round:  2
# Building:  2  - Total Profit:  -1173.7681777240707
# Cluster:  7  - Building:  10  - round:  0
# Building:  10  - Total Profit:  -1019.4104690334914
# Cluster:  7  - Building:  10  - round:  1
# Building:  10  - Total Profit:  -1019.7084659268189
# Cluster:  7  - Building:  10  - round:  2
# Building:  10  - Total Profit:  -1019.7720656797661
# Cluster:  7  - Building:  11  - round:  0
# Building:  11  - Total Profit:  -1220.902165131497
# Cluster:  7  - Building:  11  - round:  1
# Building:  11  - Total Profit:  -1219.52260913105
# Cluster:  7  - Building:  11  - round:  2
# Building:  11  - Total Profit:  -1222.198430277359

# %%
# Save results
result_df.rename(columns={'Total Profit': 'Profit'}, inplace=True)
result_df['Setup'] = 'TD3_FL'
result_df.index.name = 'Building_nr'
result_df.reset_index(inplace=True, drop=True)
os.makedirs('results', exist_ok=True)
result_df.to_csv(f'results/TD3_FL_results_setting_A.csv', index=False)
print("Final reuslt: ", result_df["Profit"].sum())
# Out:
# Final reuslt:  -107570.01243675302

# %%
import requests

def send_telegram_message(bot_token, chat_id, message):
    """Send a message to a Telegram chat via the Bot API."""
    url = f"https://api.telegram.org/bot{bot_token}/sendMessage"
    payload = {
        "chat_id": chat_id,
        "text": message,
        "parse_mode": "Markdown"
    }
    response = requests.post(url, json=payload)
    return response.json()

# Use the function
bot_token = os.getenv('TELEGRAM_BOT_TOKEN')
chat_id = os.getenv('TELEGRAM_CHAT_ID')
message = f"Script TD3 FL ist fertig am PC .81!"

result = send_telegram_message(bot_token, chat_id, message)
print(result)
# Out:
# {'ok': True, 'result': {'message_id': 20, 'from': {'id': 7071194232, 'is_bot': True, 'first_name': 'Reinforcement Learning', 'username': 'FederatedRL_Bot'}, 'chat': {'id': 5493937056, 'first_name': 'Jonas', 'last_name': 'Sievers', 'username': 'JonasSievers', 'type': 'private'}, 'date': 1715078905, 'text': 'Script TD3 FL ist fertig am PC .81!'}}
