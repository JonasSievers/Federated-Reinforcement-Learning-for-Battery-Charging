# %%
#Imports
import os
import tensorflow as tf

import sys
sys.path.insert(0, '..')
from utils.federatedAggregation import FederatedAggregation
from utils.reinforcementLearningHelper import *
from utils.federatedLearningHelper import *
# Out:
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.
#
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tf_agents\typing\types.py:114: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#Setup Environments of selected buildings for training, evaluation, and testing

environments, observation_spec, action_spec  = setup_energymanagement_environments2(num_buildings=30, ecoPriority=1, noise_scale=0)

#Check environment setup
print(
    "Batch size:", environments["train"][f"building_1"].batch_size, 
    "/ State Space: {} / Action Space: {}".format(observation_spec.shape[0], action_spec.shape[0]),
    "/ Upper bound: {}".format(round(environments["train"][f"building_1"].action_spec().maximum.item(), 3)),
)
# Out:
# Batch size: 1 / State Space: 148 / Action Space: 1 / Upper bound: 2.3

# %%
# Cluster similar buildings (K-Means with DTW)

#Set parameter
num_clusters = 9

clustered_buildings = prosumption_clustered_buildings(num_clusters)
clustered_buildings
# Out:
# {0: array([7], dtype=int64),
#  1: array([ 3,  4,  5,  9, 10, 11, 16, 23, 25, 26, 27, 30], dtype=int64),
#  2: array([1], dtype=int64),
#  3: array([24], dtype=int64),
#  4: array([12, 13, 14, 15, 19, 20, 22, 28, 29], dtype=int64),
#  5: array([ 6, 17], dtype=int64),
#  6: array([8], dtype=int64),
#  7: array([ 2, 18], dtype=int64),
#  8: array([21], dtype=int64)}

# %%
# Setup Agent networks
federated_rounds = 3
batch_size = 128
replay_buffer_capacity = 20000
initial_collect_steps = 2000
collect_steps_per_iteration = 30 
num_iterations = 10000
eval_interval = num_iterations - 1

# %%
csv_name = "NEW_FL_TD3_OnlyEmissions"

# %%
# FEDERATED LEARNING - Initalization Round 0

tf.compat.v1.reset_default_graph()
global_step = tf.compat.v1.train.get_or_create_global_step()

#Initalize a global model for each Cluster of similar buildings
for cluster in range(num_clusters):
        
        # 1. Build global agent per cluster
        first_building_in_cluster = clustered_buildings[cluster][0]
        global_td3_agent, global_eval_policy, global_collect_policy = initialize_td3_agent(
                observation_spec=observation_spec, action_spec=action_spec, global_step=global_step, environments=environments,
                )

        # 2. Initially store weights
        model_dir = os.path.join(os.getcwd(), f"models/td3/cluster_{cluster}/FLround{0}_c{num_clusters}_AvgAgg")
        os.makedirs(model_dir, exist_ok=True)
        
        save_td3_weights(global_td3_agent, model_dir)
# Out:
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
#FEDERATED LEARNING - Model training for multiple Rounds

#For each federated round and cluster
for federated_round  in range(federated_rounds):
    for cluster_number, buildings_in_cluster in clustered_buildings.items():

        #Iterate through the buildings per cluster
        print(f"Cluster {cluster_number}: Buildings {buildings_in_cluster} Federated round ---", federated_round+1, f"/ {federated_rounds}")
        local_storage = {
            "actor_weights": [], "critic_weights_1": [], "performance_metrics": []
            }
        
        for building_index in buildings_in_cluster:
            
            #0. Reset global step
            tf.compat.v1.reset_default_graph()
            global_step = tf.compat.v1.train.get_or_create_global_step()
            
            #1. Initalize local agent
            local_td3_agent, local_eval_policy, local_collect_policy = initialize_td3_agent(
                observation_spec = observation_spec, action_spec = action_spec,
                global_step = global_step, environments = environments,
                )
            
            #2. Set global weights of this training round to agent (loads the weights of last training)
            model_dir = os.path.join(os.getcwd(), f"models/td3/cluster_{cluster_number}/FLround{federated_round}_c{num_clusters}_AvgAgg")
            local_td3_agent = set_weights_to_td3_agent(local_td3_agent, model_dir)
            
            #3. Prepare training pipeline: Setup iterator, replay buffer, driver
            local_iterator, local_collect_driver, local_time_step, local_policy_state = setup_rl_training_pipeline(
                local_td3_agent, environments["train"][f"building_{building_index}"], replay_buffer_capacity,
                local_collect_policy, initial_collect_steps, collect_steps_per_iteration, batch_size
                )
            
            #4. Train, evaluate agent and store weights
            local_td3_agent, local_storage = local_agent_training_and_evaluation(
                local_iterator, local_collect_driver, local_time_step, local_policy_state, global_step, 
                local_td3_agent, local_eval_policy, local_storage, building_index, num_iterations, environments, agent_type="td3"
                )           

        # Performe Federated aggregation
        average_actor_weights = FederatedAggregation.federated_weigthed_aggregation(local_storage["actor_weights"], local_storage["performance_metrics"])
        average_critic_weights_1 = FederatedAggregation.federated_weigthed_aggregation(local_storage["critic_weights_1"], local_storage["performance_metrics"]) 
        #average_actor_weights = FederatedAggregation.federated_average_aggregation(local_storage["actor_weights"],)
        #average_critic_weights_1 = FederatedAggregation.federated_average_aggregation(local_storage["critic_weights_1"],) 
       
        #Save federated weights for next round (Round + 1)
        model_dir = os.path.join(os.getcwd(), f"models/td3/cluster_{cluster_number}/FLround{federated_round+1}_c{num_clusters}_AvgAgg")
        os.makedirs(model_dir, exist_ok=True)
        save_federated_td3_weights(model_dir, average_actor_weights, average_critic_weights_1)
# Out:
# Cluster 0: Buildings [7] Federated round --- 1 / 3
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\.venv\lib\site-packages\tensorflow\python\autograph\impl\api.py:377: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.
# Return:  -3108.729
# Cluster 1: Buildings [ 3  4  5  9 10 11 16 23 25 26 27 30] Federated round --- 1 / 3
# Return:  -2336.6667
# Return:  -4259.523
# Return:  -2784.078
# WARNING:tensorflow:5 out of the last 5 calls to <function AverageReturnMetric.reset at 0x000002A34C275F30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <bound method DynamicEpisodeDriver.run of <tf_agents.drivers.dynamic_episode_driver.DynamicEpisodeDriver object at 0x000002A37FD23D30>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function TFDeque.mean at 0x000002A34C275630> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Return:  -3939.0427
# WARNING:tensorflow:6 out of the last 6 calls to <function AverageReturnMetric.reset at 0x000002A34C275000> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <bound method DynamicEpisodeDriver.run of <tf_agents.drivers.dynamic_episode_driver.DynamicEpisodeDriver object at 0x000002A38D9AE560>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TFDeque.mean at 0x000002A33FB66D40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Return:  -5225.4043
# Return:  -3535.6196
# Return:  -6490.112
# Return:  -3513.5203
# Return:  -3897.312
# Return:  -5596.99
# Return:  -3901.2424
# Return:  -1894.3599
# Cluster 2: Buildings [1] Federated round --- 1 / 3
# Return:  -4262.3066
# Cluster 3: Buildings [24] Federated round --- 1 / 3
# Return:  -1794.7946
# Cluster 4: Buildings [12 13 14 15 19 20 22 28 29] Federated round --- 1 / 3
# Return:  -3632.477
# Return:  -2548.963
# Return:  -1594.8307
# Return:  -1599.3652
# Return:  -1034.6976
# Return:  -2998.782
# Return:  -3243.0837
# Return:  -2157.0056
# Return:  -3125.6775
# Cluster 5: Buildings [ 6 17] Federated round --- 1 / 3
# Return:  -7711.424
# Return:  -5931.8
# Cluster 6: Buildings [8] Federated round --- 1 / 3
# Return:  -9683.7295
# Cluster 7: Buildings [ 2 18] Federated round --- 1 / 3
# Return:  -6029.3926
# Return:  -5777.924
# Cluster 8: Buildings [21] Federated round --- 1 / 3
# Return:  -8865.871
# Cluster 0: Buildings [7] Federated round --- 2 / 3
# Return:  -2892.5254
# Cluster 1: Buildings [ 3  4  5  9 10 11 16 23 25 26 27 30] Federated round --- 2 / 3
# Return:  -2223.9048
# Return:  -3858.765
# Return:  -3001.5425
# Return:  -3974.7815
# Return:  -5115.058
# Return:  -3368.9749
# Return:  -6212.869
# Return:  -3702.9597
# Return:  -3775.7546
# Return:  -5802.6157
# Return:  -4099.7876
# Return:  -2040.9266
# Cluster 2: Buildings [1] Federated round --- 2 / 3
# Return:  -3949.223
# Cluster 3: Buildings [24] Federated round --- 2 / 3
# Return:  -1561.6077
# Cluster 4: Buildings [12 13 14 15 19 20 22 28 29] Federated round --- 2 / 3
# Return:  -3495.5186
# Return:  -2314.5476
# Return:  -1992.4312
# Return:  -1591.3392
# Return:  -1041.2408
# Return:  -3059.5918
# Return:  -2880.4734
# Return:  -2118.0303
# Return:  -2895.058
# Cluster 5: Buildings [ 6 17] Federated round --- 2 / 3
# Return:  -7848.196
# Return:  -5137.129
# Cluster 6: Buildings [8] Federated round --- 2 / 3
# Return:  -9925.64
# Cluster 7: Buildings [ 2 18] Federated round --- 2 / 3
# Return:  -5873.292
# Return:  -5451.486
# Cluster 8: Buildings [21] Federated round --- 2 / 3
# Return:  -8953.973
# Cluster 0: Buildings [7] Federated round --- 3 / 3
# Return:  -2728.645
# Cluster 1: Buildings [ 3  4  5  9 10 11 16 23 25 26 27 30] Federated round --- 3 / 3
# Return:  -2408.326
# Return:  -3644.529
# Return:  -2912.7273
# Return:  -3616.372
# Return:  -5055.3726
# Return:  -3344.5083
# Return:  -6228.826
# Return:  -3542.8328
# Return:  -4064.3748
# Return:  -5621.71
# Return:  -3737.215
# Return:  -2270.7424
# Cluster 2: Buildings [1] Federated round --- 3 / 3
# Return:  -3648.2542
# Cluster 3: Buildings [24] Federated round --- 3 / 3
# Return:  -1468.1914
# Cluster 4: Buildings [12 13 14 15 19 20 22 28 29] Federated round --- 3 / 3
# Return:  -3139.7449
# Return:  -2400.4246
# Return:  -1542.1646
# Return:  -1648.7496
# Return:  -17201.963
# Return:  -3013.6365
# Return:  -2795.301
# Return:  -2180.2427
# Return:  -3211.0774
# Cluster 5: Buildings [ 6 17] Federated round --- 3 / 3
# Return:  -7845.435
# Return:  -5262.231
# Cluster 6: Buildings [8] Federated round --- 3 / 3
# Return:  -9924.663
# Cluster 7: Buildings [ 2 18] Federated round --- 3 / 3
# Return:  -6029.247
# Return:  -5348.821
# Cluster 8: Buildings [21] Federated round --- 3 / 3
# Return:  -8790.454

# %%
# LOCAL REFITTING AND EVALUATION

best_federated_round = 3
num_rounds=3
num_test_iterations = 1

result_df = pd.DataFrame(columns=['Building', 'Total Profit'])

for cluster_number, buildings_in_cluster in clustered_buildings.items():
    for building_index in buildings_in_cluster:
        
        for round in range(num_rounds):
            print("Cluster: ", cluster_number, " - Building: ", building_index, " - round: ", round)
            
            #0. Reset global step
            tf.compat.v1.reset_default_graph()
            global_step = tf.compat.v1.train.get_or_create_global_step()

            #1. Initalize local agent
            tf_td3_agent, eval_policy, collect_policy = initialize_td3_agent(
                observation_spec = observation_spec, action_spec = action_spec,
                global_step = global_step, environments = environments,
                )
            
            #2. Set global weights of this training round to agent (loads the weights of last training)
            model_dir = os.path.join(os.getcwd(), f"models/td3/cluster_{cluster_number}/FLround{best_federated_round}_c{num_clusters}_AvgAgg")
            tf_agent = set_weights_to_td3_agent(tf_td3_agent, model_dir)

            #3. Prepare training pipeline: Setup iterator, replay buffer, driver
            iterator, collect_driver, time_step, policy_state = setup_rl_training_pipeline(
                tf_td3_agent, environments["train"][f"building_{building_index}"], replay_buffer_capacity,
                collect_policy, initial_collect_steps, collect_steps_per_iteration, batch_size
                )
            
            #4. Setup wandb logging
            artifact = initialize_wandb_logging(name=f"{csv_name}_Home{building_index}_rd{round}", num_iterations=num_iterations)
            
            #5. Train, evaluate agent and store weights
            result_df, metrics = agent_training_and_evaluation(global_step, num_test_iterations, collect_driver, 
                time_step, policy_state, iterator, tf_td3_agent, eval_policy, building_index, result_df, eval_interval, environments)
            
            #6. End and log wandb
            end_and_log_wandb(metrics, artifact)
# Out:
# Cluster:  0  - Building:  7  - round:  0
# c:\Users\rs1044\Documents\GitHub\Federated-Reinforcement-Learning-for-Battery-Charging\src\notebooks\..\utils\reinforcementLearningHelper.py:443: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result_df = pd.concat(
# Building:  7  - Total Profit:  -557.6524727633315  - Total Emissions:  1966.1402860521314
# Cluster:  0  - Building:  7  - round:  1
# WARNING:tensorflow:5 out of the last 10004 calls to <bound method DynamicStepDriver.run of <tf_agents.drivers.dynamic_step_driver.DynamicStepDriver object at 0x000002A33D048190>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Building:  7  - Total Profit:  -557.7504657031121  - Total Emissions:  1961.6498413646352
# Cluster:  0  - Building:  7  - round:  2
# WARNING:tensorflow:6 out of the last 10005 calls to <bound method DynamicStepDriver.run of <tf_agents.drivers.dynamic_step_driver.DynamicStepDriver object at 0x000002A33FC4F4C0>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Building:  7  - Total Profit:  -557.4995503034553  - Total Emissions:  1957.217648661417
# Cluster:  1  - Building:  3  - round:  0
# WARNING:tensorflow:5 out of the last 10004 calls to <bound method TFAgent.train of <tf_agents.agents.td3.td3_agent.Td3Agent object at 0x000002A38D986F50>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Building:  3  - Total Profit:  -259.5309662825039  - Total Emissions:  1033.8790514316972
# Cluster:  1  - Building:  3  - round:  1
# WARNING:tensorflow:6 out of the last 10005 calls to <bound method TFAgent.train of <tf_agents.agents.td3.td3_agent.Td3Agent object at 0x000002A33FCC1870>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# Cluster:  5  - Building:  17  - round:  2
# Building:  17  - Total Profit:  -1866.1638468118042  - Total Emissions:  5890.833658727214
# Cluster:  6  - Building:  8  - round:  0
# Building:  8  - Total Profit:  -2772.406656191786  - Total Emissions:  9455.22107873689
# Cluster:  6  - Building:  8  - round:  1
# Building:  8  - Total Profit:  -2774.769148290251  - Total Emissions:  9427.95953028948
# Cluster:  6  - Building:  8  - round:  2
# Building:  8  - Total Profit:  -2773.5393980405033  - Total Emissions:  9451.772160886558
# Cluster:  7  - Building:  2  - round:  0
# Building:  2  - Total Profit:  -1167.979419513645  - Total Emissions:  3650.560920026439
# Cluster:  7  - Building:  2  - round:  1
# Building:  2  - Total Profit:  -1168.2994257158198  - Total Emissions:  3645.0881165140163
# Cluster:  7  - Building:  2  - round:  2
# Building:  2  - Total Profit:  -1168.979376602432  - Total Emissions:  3645.074236612893
# Cluster:  7  - Building:  18  - round:  0
# Building:  18  - Total Profit:  -1585.2996872428555  - Total Emissions:  5263.743090156197
# Cluster:  7  - Building:  18  - round:  1
# Building:  18  - Total Profit:  -1590.9936526103118  - Total Emissions:  5224.603202569033
# Cluster:  7  - Building:  18  - round:  2
# Building:  18  - Total Profit:  -1588.7052524427284  - Total Emissions:  5225.687136885422
# Cluster:  8  - Building:  21  - round:  0
# Building:  21  - Total Profit:  -1961.2092584105608  - Total Emissions:  6683.501059498189
# Cluster:  8  - Building:  21  - round:  1
# Building:  21  - Total Profit:  -1966.111472737911  - Total Emissions:  6585.385376491924
# Cluster:  8  - Building:  21  - round:  2
# Building:  21  - Total Profit:  -1961.1187851680563  - Total Emissions:  6671.11341386047

# %%
# Save results
result_df['Setup'] = csv_name
result_df.index.name = 'Building_nr'
result_df.reset_index(inplace=True, drop=True)
os.makedirs('results', exist_ok=True)
result_df.to_csv(f'results/{csv_name}.csv', index=False)

print("Final result: ", result_df["Total Profit"].sum())
# Out:
# Final result:  -96946.898862732

# %%
import requests

def send_telegram_message(bot_token, chat_id, message):
    """Send a message to a Telegram chat via the Bot API."""
    url = f"https://api.telegram.org/bot{bot_token}/sendMessage"
    payload = {
        "chat_id": chat_id,
        "text": message,
        "parse_mode": "Markdown"
    }
    response = requests.post(url, json=payload)
    return response.json()

# Use the function
bot_token = os.getenv('TELEGRAM_BOT_TOKEN')
chat_id = os.getenv('TELEGRAM_CHAT_ID')
message = f"Script .81!"

result = send_telegram_message(bot_token, chat_id, message)
print(result)
# Out:
# {'ok': True, 'result': {'message_id': 204, 'from': {'id': 7071194232, 'is_bot': True, 'first_name': 'Reinforcement Learning', 'username': 'FederatedRL_Bot'}, 'chat': {'id': 5493937056, 'first_name': 'Jonas', 'last_name': 'Sievers', 'username': 'JonasSievers', 'type': 'private'}, 'date': 1721705119, 'text': 'Script .81!'}}

# %%
result_df['Total Emissions'].sum()
# Out:
# 335166.364907368

# %%
std_dev = result_df.groupby('Building')['Total Emissions'].std().mean()
std_dev
# Out:
# 7.8327796631229605
